# %%
#Getting data like in DataGet.ipynb tests

from MetaTrader5 import *
MT5Initialize()
MT5WaitForTerminal()
from datetime import datetime as dt
#Tuple
eurusd_rates = MT5CopyRatesRange("EURUSD", MT5_TIMEFRAME_H4, dt(2018,4,22,0), dt(2018,4,29,0))
eurusd_h8 = MT5CopyRatesRange("EURUSD", MT5_TIMEFRAME_H8, dt(2018,4,15,0), dt(2018,4,29,0))
MT5Shutdown()
# Out:
# True

# %%
lineA, lineB = candles_draw(eurusd_rates)
print(ang(lineA,lineB))
# Out:
# 0.1996699484112532

# %%
lineA, lineB = candles_draw(eurusd_h8)
print(ang(lineA,lineB))
# Out:
# 0.1332583355648583

# %% [markdown]
# Angles (part4):
#
# dt(2018,6,10,0), dt(2018,6,17,0) 0.24227366413121898
# dt(2018,6,3,0), dt(2018,6,17,0) 0.007020381086285437
#
# dt(2018,6,3,0), dt(2018,6,11,0) 0.15435942771476574
# dt(2018,5,27,0), dt(2018,6,11,0) 0.08443095512857914
#
# dt(2018,5,27,0), dt(2018,6,3,0) 0.05253135623319194
# dt(2018,5,20,0), dt(2018,6,3,0) 0.07815235774305451
#
# dt(2018,5,20,0), dt(2018,5,27,0) 0.10686294188727705 m: -0.001988779755309027
# dt(2018,5,13,0), dt(2018,5,27,0) 0.10475738284113868 m: -0.0016689696186200707
#
# dt(2018,5,13,0), dt(2018,5,20,0) 0.24779460740124812
# dt(2018,5,6,0), dt(2018,5,20,0) 0.055040375514393426
#
# dt(2018,5,6,0), dt(2018,5,13,0) 0.02467529587296601
# dt(2018,4,29,0), dt(2018,5,13,0) 0.10080320901609416 m: -0.0016689696186200707
#
# dt(2018,4,29,0), dt(2018,5,6,0) 0.19802183829099138
# dt(2018,4,22,0), dt(2018,5,6,0) 0.1451906018846288
#
# dt(2018,4,22,0), dt(2018,4,29,0) 0.1996699484112532
# dt(2018,4,15,0), dt(2018,4,29,0) 0.1332583355648583

# %% [markdown]
# Angles (part3):
#
# dt(2018,8,5,0), dt(2018,8,12,0) 0.08269782824208209
# dt(2018,7,29,0), dt(2018,8,12,0) 0.0811514359996462
#
# dt(2018,7,29,0), dt(2018,8,5,0) 0.14410820526917767
# dt(2018,7,22,0), dt(2018,8,5,0) 0.04113117750304495
#
# dt(2018,7,22,0), dt(2018,7,29,0) 0.08051052327328724
# dt(2018,7,15,0), dt(2018,7,29,0) 0.0046952909679797376
#
# dt(2018,7,15,0), dt(2018,7,22,0) 0.049580020471347
# dt(2018,7,8,0), dt(2018,7,22,0) 0.04052140553008023
#
# dt(2018,7,8,0), dt(2018,7,15,0) 0.1478610225969817
# dt(2018,7,1,0), dt(2018,7,15,0) 0.024296223829186146
#
# dt(2018,7,1,0), dt(2018,7,8,0) 0.10831680920992616 m: 0.001897201334773962
# dt(2018,6,24,0), dt(2018,7,8,0) 0.02681486730272976
#
# dt(2018,6,24,0), dt(2018,7,1,0) 0.09409704815541829 m: -0.0018062302557772603
# dt(2018,6,17,0), dt(2018,7,1,0) 0.01889627329976484
#
# dt(2018,6,17,0), dt(2018,6,24,0) 0.029485845898816455
# dt(2018,6,10,0), dt(2018,6,24,0) 0.10959843334577886 m: -0.0018956170006531746

# %% [markdown]
# Angles (part2):
#
# dt(2018,9,30,0), dt(2018,10,7,0) 0.12082342721138226
# dt(2018,9,23,0), dt(2018,10,7,0) 0.1471492381421845
#
# dt(2018,9,23,0), dt(2018,9,30,0) 0.178710246622232
# dt(2018,9,16,0), dt(2018,9,30,0) 0.007451266104866792
#
# dt(2018,9,16,0), dt(2018,9,23,0) 0.14728131295177851
# dt(2018,9,9,0), dt(2018,9,23,0) 0.07907168104564974
#
# dt(2018,9,9,0), dt(2018,9,16,0) 0.14459155167839455
# dt(2018,9,2,0), dt(2018,9,16,0) 0.022791348768380213
#
# dt(2018,9,2,0), dt(2018,9,9,0) 0.009822242775083341
# dt(2018,8,26,0), dt(2018,9,9,0) 0.04510380609034895
#
# dt(2018,8,26,0), dt(2018,9,2,0) 0.0010110572662654198
# dt(2018,8,19,0), dt(2018,9,2,0) 0.10971976514370373 m: 0.0018646173238370206
#
# dt(2018,8,19,0), dt(2018,8,26,0) 0.18651182578693423
# dt(2018,8,12,0), dt(2018,8,26,0) 0.12414735262437904
#
# dt(2018,8,12,0), dt(2018,8,19,0) 0.007853664369823947
# dt(2018,8,5,0), dt(2018,8,19,0) 0.13130569691653488

# %% [markdown]
# Angles (part1):
#
# dt(2018,11,25,0), dt(2018,12,2,0) 0.044074275763901896
# dt(2018,11,18,0), dt(2018,12,2,0) 0.0409169573279177
#
# dt(2018,11,18,0), dt(2018,11,25,0) 0.07267216873586684
# dt(2018,11,11,0), dt(2018,11,25,0) 0.07845679887521928
#
# dt(2018,11,11,0), dt(2018,11,18,0) 0.13211325378010227
# dt(2018,11,4,0), dt(2018,11,18,0) 0.060549431329901586
#
# dt(2018,11,4,0), dt(2018,11,11,0) 0.04406050951175992
# dt(2018,10,28,0), dt(2018,11,11,0) 0.015453860227389276
#
# dt(2018,10,28,0), dt(2018,11,4,0) 0.020273145192688108
# dt(2018,10,21,0), dt(2018,11,4,0) 0.0509584158275177
#
# dt(2018,10,21,0), dt(2018,10,28,0) 0.1712398133844697 m: -0.003088615128145826
# dt(2018,10,14,0), dt(2018,10,28,0) 0.09240908638555571
#
# dt(2018,10,14,0), dt(2018,10,21,0) 0.14770271137222452 m: -0.0027065606228067257
# dt(2018,10,7,0), dt(2018,10,21,0) 0.005507505791273727
#
# dt(2018,10,7,0), dt(2018,10,14,0) 0.1306655072984348
# dt(2018,9,30,0), dt(2018,10,14,0) 0.011906114678696546

# %%
#Converting data

def trend_dir(quotes):
    import pandas as pd
    import matplotlib.dates as mdates
    import numpy as np
    _quotes = pd.DataFrame(list(quotes), columns=['Time','Open','High','Low','Close',
                                                   'Tick_Vol','Spread','Real_Vol']).set_index('Time')
    y = np.array(_quotes[['Open', 'High', 'Low', 'Close']]).ravel()
    x = np.array(_quotes.index).ravel()
    x = np.array([(lambda d: mdates.date2num(d))(d) for d in x for _ in (0,1,2,3)])
    A = np.vstack([x, np.ones(len(x))]).T
    m, c = np.linalg.lstsq(A, y, rcond=None)[0]
    if m < 0.0016:
        _dir = 1
    elif m > 0.0016:
        _dir = 4
    elif m <= 0:
        _dir = 2
    else:
        _dir = 3
    #print('m:',m)
    return _dir

# %%
import math
def dot(vA, vB):
    return vA[0]*vB[0]+vA[1]*vB[1]
def ang(lineA, lineB):
    # Get nicer vector form
    vA = [(lineA[0][0]-lineA[1][0]), (lineA[0][1]-lineA[1][1])]
    vB = [(lineB[0][0]-lineB[1][0]), (lineB[0][1]-lineB[1][1])]
    # Get dot prod
    dot_prod = dot(vA, vB)
    # Get magnitudes
    magA = dot(vA, vA)**0.5
    magB = dot(vB, vB)**0.5
    # Get cosine value
    cos_ = dot_prod/magA/magB
    # Get angle in radians and then convert to degrees
    angle = math.acos(dot_prod/magB/magA)
    # Basically doing angle <- angle mod 360
    ang_deg = math.degrees(angle)%360

    if ang_deg-180>=0:
        # As in if statement
        return 360 - ang_deg
    else: 

        return ang_deg

# %%
#drawing data

def candles_draw(quotes):
    import pandas as pd
    import matplotlib.dates as mdates
    import matplotlib.pyplot as plt
    from mpl_finance import candlestick_ohlc as cohlc
    from pandas.plotting import register_matplotlib_converters
    import numpy as np
    register_matplotlib_converters()
    _quotes = pd.DataFrame(list(quotes), columns=['Time','Open','High','Low','Close',
                                                       'Tick_Vol','Spread','Real_Vol']).set_index('Time')
    _quotes['Time2'] = _quotes.index
    _quotes['Time2'] = _quotes['Time2'].apply(lambda d: mdates.date2num(d.to_pydatetime()))
    tuples = [tuple(x) for x in _quotes[['Time2', 'Open', 'High', 'Low', 'Close']].values]
    y = np.array([item[trend_dir(quotes)] for item in quotes])
    x = np.array(_quotes.index).ravel()
    x = np.array([(lambda d: mdates.date2num(d))(d) for d in x])
    A = np.vstack([x, np.ones(len(x))]).T
    m, c = np.linalg.lstsq(A, y, rcond=None)[0]
    OX_ticks_str = [dateFef.strftime('%Y-%m-%d %H:%M') for dateFef in _quotes.index]
    OX_ticks_pos = range(len(_quotes['Time2']))
    fig, ax = plt.subplots()
    ax.xaxis_date()
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d %H:%M"))
    plt.xticks(_quotes.index, rotation=90)
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('EURUSD')
    plt.plot(x, x*m+c, 'b')
    cohlc(ax, tuples, width=.1, colorup='g', alpha=.4)
    return ((min(x),min(x)*m+c),(max(x),max(x)*m+c)),((min(x),min(x)*m+c),(max(x),min(x)*m+c))

# %%
lineA, lineB = candles_draw(eurusd_rates)
print(ang(lineA,lineB))
lineA, lineB = candles_draw(eurusd_h8)
print(ang(lineA,lineB))
# Out:
# 0.14459155167839455
# 0.022791348768380213

# %% [markdown]
# Maybe examined:
# dt(2019,5,5,0), dt(2019,5,12,0) - 2019-05-09 11:00 (size of peak above the blue line)
# dt(2019,4,21,0), dt(2019,4,28,0) - 2019-04-24 07:00 (size of peak below the blue line)
# dt(2019,4,14,0), dt(2019,4,21,0) - 2019-04-16 11:00 (is it crossline)
# dt(2019,4,14,0), dt(2019,4,21,0) - 2019-04-16 15:00 (is it crossline)
# dt(2019,3,31,0), dt(2019,4,7,0) - whole line (is it sideway trend)
# dt(2019,3,24,0), dt(2019,3,31,0) - whole graph (many examples with similar questions previously asked)
# dt(2019,3,17,0), dt(2019,3,24,0) - whole line (sideway for sure)
# dt(2019,3,10,0), dt(2019,3,17,0) - whole graph (a lot of crosslines)
# dt(2019,3,3,0), dt(2019,3,10,0) - several candles(size of peak above the blue line)
# dt(2019,2,24,0), dt(2019,3,3,0) - whole line (angle of blue line)
# dt(2019,2,10,0), dt(2019,2,17,0) - angle of slope may help find pattern for slope
# dt(2018,12,30,0), dt(2019,1,6,0) - in H4 it's bearish trend in H8 (2week) it's flat, what should i do don't take slope as possible to get into market?
# dt(2018,12,16,0), dt(2018,12,23,0) - too big difference betwen H4 and H8 (2week) slopes
# dt(2018,11,25,0), dt(2018,12,2,0) - H4 bullish trend and H8 (2week) bearish trend
